# %%
import pandas as pd

# %%
df1 = pd.read_csv("Deltavariant06.csv")
df2 = pd.read_csv("Deltavariant07.csv")
df3 = pd.read_csv("Deltavariant08.csv")
df4 = pd.read_csv("Deltavariant09.csv")
df5= pd.read_csv("Deltavariant10.csv")

final = df1.append([df2,df3,df4,df5])
final
# Out:
#       Unnamed: 0                           _type  \
# 0              0  snscrape.modules.twitter.Tweet
# 1              1  snscrape.modules.twitter.Tweet
# 2              2  snscrape.modules.twitter.Tweet
# 3              3  snscrape.modules.twitter.Tweet
# 4              4  snscrape.modules.twitter.Tweet
# ...          ...                             ...
# 5874         156  snscrape.modules.twitter.Tweet
# 5875         157  snscrape.modules.twitter.Tweet
# 5876         158  snscrape.modules.twitter.Tweet
# 5877         159  snscrape.modules.twitter.Tweet
# 5878         160  snscrape.modules.twitter.Tweet
#
#                                                     url  \
# 0     https://twitter.com/antohyd2/status/1399870695...
# 1     https://twitter.com/cass_lyons/status/13998460...
# 2     https://twitter.com/MedicalScitech/status/1399...
# 3     https://twitter.com/ElaineyP_/status/139984198...
# 4     https://twitter.com/geinorstyles/status/139983...
# ...

# %%
final.to_csv('Deltavariant06-10.csv')
