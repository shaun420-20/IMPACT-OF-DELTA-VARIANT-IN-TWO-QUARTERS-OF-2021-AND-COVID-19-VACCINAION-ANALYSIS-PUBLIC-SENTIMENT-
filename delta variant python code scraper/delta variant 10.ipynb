# %%
# Imports
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# Script Author: Martin Beck
# Medium Article Follow-Along: https://medium.com/better-programming/how-to-scrape-tweets-with-snscrape-90124ed006af

# Pip install the command below if you don't have the development version of snscrape 
# !pip install git+https://github.com/JustAnotherArchivist/snscrape.git

# Run the below command if you don't already have Pandas
# !pip install pandas

# Imports
import os
import pandas as pd

# Below are two ways of scraping using CLI commands.
# Comment or uncomment as you need. If you currently run the script as is it will scrape both queries
# then output two different csv files.



# Query by text search
# Setting variables to be used in format string command below
tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-01"
until_date = "2021-10-02"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy1 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy1



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-02"
until_date = "2021-08-03"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy2 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy2



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-03"
until_date = "2021-10-04"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy3 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy3


tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-04"
until_date = "2021-10-05"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy4 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy4









tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-05"
until_date = "2021-10-06"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy5 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy5


tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-06"
until_date = "2021-10-07"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy6 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy6


tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-07"
until_date = "2021-10-08"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy7 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy7


tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-08"
until_date = "2021-10-09"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy8 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy8



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-09"
until_date = "2021-10-10"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy9 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy9




tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-10"
until_date = "2021-10-11"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy10 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy10



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-11"
until_date = "2021-10-12"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy11= pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy11




tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-12"
until_date = "2021-10-13"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy12 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy12



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-13"
until_date = "2021-10-14"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy13 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy13



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-14"
until_date = "2021-10-15"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy14 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy14



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-15"
until_date = "2021-10-16"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy15 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy15



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-16"
until_date = "2021-10-17"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy16 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy16


tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-17"
until_date = "2021-10-18"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy17 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy17




tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-18"
until_date = "2021-10-19"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy18 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy18



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-19"
until_date = "2021-10-20"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy19 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy19






tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-20"
until_date = "2021-10-21"
8
# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy20 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy20


tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-21"
until_date = "2021-10-22"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy21 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy21




tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-22"
until_date = "2021-10-23"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy22 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy22



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-23"
until_date = "2021-10-24"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy23 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy23





tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-24"
until_date = "2021-10-25"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy24 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy24



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-25"
until_date = "2021-10-26"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy25 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy25


tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-26"
until_date = "2021-10-27"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy26 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy26



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-27"
until_date = "2021-10-28"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy27 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy27


tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-28"
until_date = "2021-10-29"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy28= pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy28


tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-29"
until_date = "2021-10-30"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy29 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy29



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-30"
until_date = "2021-10-31"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy30 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy30


tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-10-31"
until_date = "2021-11-01"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_dfy31 = pd.read_json('text-query-tweets.json', lines=True)
tweets_dfy31
# Out:
#                               _type  \
# 0    snscrape.modules.twitter.Tweet
# 1    snscrape.modules.twitter.Tweet
# 2    snscrape.modules.twitter.Tweet
# 3    snscrape.modules.twitter.Tweet
# 4    snscrape.modules.twitter.Tweet
# ..                              ...
# 156  snscrape.modules.twitter.Tweet
# 157  snscrape.modules.twitter.Tweet
# 158  snscrape.modules.twitter.Tweet
# 159  snscrape.modules.twitter.Tweet
# 160  snscrape.modules.twitter.Tweet
#
#                                                    url  \
# 0    https://twitter.com/AssetTVUS/status/145495764...
# 1    https://twitter.com/jamaicanrabbit5/status/145...
# 2    https://twitter.com/myknittingwool/status/1454...
# 3    https://twitter.com/GoVeganWorld/status/145494...
# 4    https://twitter.com/OurSantaMonica/status/1454...
# ..                                                 ...
# 156  https://twitter.com/VippusaO/status/1454605840...
# 157  https://twitter.com/Zahidul91891192/status/145...
# 158  https://twitter.com/ADBYNOT/status/14546053578...
# 159  https://twitter.com/InvariantPersp1/status/145...
# 160  https://twitter.com/1SilvanaA/status/145460296...
#
#                          date  \
# 0   2021-10-31 23:45:08+00:00
# 1   2021-10-31 23:44:07+00:00
# 2   2021-10-31 23:11:03+00:00
# 3   2021-10-31 23:08:30+00:00
# 4   2021-10-31 22:57:36+00:00
# ..                        ...
# 156 2021-10-31 00:27:12+00:00
# 157 2021-10-31 00:26:20+00:00
# 158 2021-10-31 00:25:17+00:00
# 159 2021-10-31 00:17:23+00:00
# 160 2021-10-31 00:15:46+00:00
#
#                                                content  \
# 0    .@GuggenheimPtnrs’s Scott Minerd analyses the ...
# 1    COVID-19 vaccine mandates are moving forward a...
# 2    @kazza264 @VictorianCHO Will we  be informed o...
# 3    #COVID19 #DeltaVariant #Halloween #halloween20...
# 4    Santa Monica #Weather Report:\n\n“Nice”\n\n#De...
# ..                                                 ...
# 156  THE VIRAL LOAD FROM THE DELTA VARIANT IS 1200 ...
# 157  New type of 'Delta variant' is spreading in De...
# 158  Iove seeing everyone #vaccinated lying to them...
# 159  #coronavirus #SARSCoV2 #COVID19 #DeltaVariant ...
# 160  #Covid_19 #COVIDー19 #Delta #DeltaVariant \nUS ...
#
#                                        renderedContent                   id  \
# 0    .@GuggenheimPtnrs’s Scott Minerd analyses the ...  1454957642175160321
# 1    COVID-19 vaccine mandates are moving forward a...  1454957385907322888
# 2    @kazza264 @VictorianCHO Will we  be informed o...  1454949064450076673
# 3    #COVID19 #DeltaVariant #Halloween #halloween20...  1454948422746787841
# 4    Santa Monica #Weather Report:\n\n“Nice”\n\n#De...  1454945678820446220
# ..                                                 ...                  ...
# 156  THE VIRAL LOAD FROM THE DELTA VARIANT IS 1200 ...  1454605840326004745
# 157  New type of 'Delta variant' is spreading in De...  1454605622469697539
# 158  Iove seeing everyone #vaccinated lying to them...  1454605357825724416
# 159  #coronavirus #SARSCoV2 #COVID19 #DeltaVariant ...  1454603370056929282
# 160  #Covid_19 #COVIDー19 #Delta #DeltaVariant \nUS ...  1454602965696798722
#
#                                                   user  replyCount  \
# 0    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 3    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 4    {'_type': 'snscrape.modules.twitter.User', 'us...           1
# ..                                                 ...         ...
# 156  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 157  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 158  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 159  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 160  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#      retweetCount  likeCount  ...  \
# 0               0          0  ...
# 1               0          0  ...
# 2               0          2  ...
# 3               0          2  ...
# 4               4         34  ...
# ..            ...        ...  ...
# 156             0          0  ...
# 157             0          1  ...
# 158             2          2  ...
# 159             0          0  ...
# 160             0          0  ...
#
#                                                  media  retweetedTweet  \
# 0    [{'_type': 'snscrape.modules.twitter.Video', '...             NaN
# 1    [{'_type': 'snscrape.modules.twitter.Video', '...             NaN
# 2                                                 None             NaN
# 3                                                 None             NaN
# 4    [{'_type': 'snscrape.modules.twitter.Photo', '...             NaN
# ..                                                 ...             ...
# 156  [{'_type': 'snscrape.modules.twitter.Video', '...             NaN
# 157  [{'_type': 'snscrape.modules.twitter.Photo', '...             NaN
# 158  [{'_type': 'snscrape.modules.twitter.Gif', 'th...             NaN
# 159                                               None             NaN
# 160  [{'_type': 'snscrape.modules.twitter.Photo', '...             NaN
#
#                                            quotedTweet inReplyToTweetId  \
# 0                                                 None              NaN
# 1                                                 None              NaN
# 2                                                 None     1.454947e+18
# 3    {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 4                                                 None              NaN
# ..                                                 ...              ...
# 156                                               None              NaN
# 157                                               None              NaN
# 158                                               None              NaN
# 159  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 160                                               None              NaN
#
#                                          inReplyToUser  \
# 0                                                 None
# 1                                                 None
# 2    {'_type': 'snscrape.modules.twitter.User', 'us...
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 156                                               None
# 157                                               None
# 158                                               None
# 159                                               None
# 160                                               None
#
#                                         mentionedUsers coordinates place  \
# 0    [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 1                                                 None         NaN   NaN
# 2    [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 3                                                 None         NaN   NaN
# 4                                                 None         NaN   NaN
# ..                                                 ...         ...   ...
# 156                                               None         NaN   NaN
# 157                                               None         NaN   NaN
# 158                                               None         NaN   NaN
# 159                                               None         NaN   NaN
# 160                                               None         NaN   NaN
#
#                                               hashtags  cashtags
# 0                                       [DeltaVariant]       NaN
# 1    [COVID19, coronavirus, CoronavirusOutbreak, Ja...       NaN
# 2                   [DeltaVariant, healthbeforeProfit]       NaN
# 3    [COVID19, DeltaVariant, Halloween, halloween20...       NaN
# 4    [Weather, DeltaVariant, MyDayInLA, California,...       NaN
# ..                                                 ...       ...
# 156                                     [DeltaVariant]       NaN
# 157                            [DeltaVariant, Denmark]       NaN
# 158  [vaccinated, breakthrough, VaccineFailure, COV...       NaN
# 159  [coronavirus, SARSCoV2, COVID19, DeltaVariant,...       NaN
# 160          [Covid_19, COVIDー19, Delta, DeltaVariant]       NaN
#
# [161 rows x 28 columns]

# %%
result = tweets_dfy1.append([tweets_dfy2,tweets_dfy3,tweets_dfy4,tweets_dfy5,tweets_dfy6,tweets_dfy7,tweets_dfy8,tweets_dfy9,tweets_dfy10,tweets_dfy11,tweets_dfy12,tweets_dfy13,tweets_dfy14,tweets_dfy15,tweets_dfy16,tweets_dfy17,tweets_dfy18,tweets_dfy19,tweets_dfy20,tweets_dfy21,tweets_dfy22,tweets_dfy23,tweets_dfy24,tweets_dfy25,tweets_dfy26,tweets_dfy27,tweets_dfy28,tweets_dfy29,tweets_dfy30,tweets_dfy31])
result
# Out:
#                               _type  \
# 0    snscrape.modules.twitter.Tweet
# 1    snscrape.modules.twitter.Tweet
# 2    snscrape.modules.twitter.Tweet
# 3    snscrape.modules.twitter.Tweet
# 4    snscrape.modules.twitter.Tweet
# ..                              ...
# 156  snscrape.modules.twitter.Tweet
# 157  snscrape.modules.twitter.Tweet
# 158  snscrape.modules.twitter.Tweet
# 159  snscrape.modules.twitter.Tweet
# 160  snscrape.modules.twitter.Tweet
#
#                                                    url  \
# 0    https://twitter.com/Adinoadonai/status/1444089...
# 1    https://twitter.com/FluoridePoison/status/1444...
# 2    https://twitter.com/Jack4Ward/status/144408644...
# 3    https://twitter.com/sofistic8ed/status/1444085...
# 4    https://twitter.com/IslandSocTrends/status/144...
# ..                                                 ...
# 156  https://twitter.com/VippusaO/status/1454605840...
# 157  https://twitter.com/Zahidul91891192/status/145...
# 158  https://twitter.com/ADBYNOT/status/14546053578...
# 159  https://twitter.com/InvariantPersp1/status/145...
# 160  https://twitter.com/1SilvanaA/status/145460296...
#
#                          date  \
# 0   2021-10-01 23:59:14+00:00
# 1   2021-10-01 23:50:06+00:00
# 2   2021-10-01 23:46:52+00:00
# 3   2021-10-01 23:43:42+00:00
# 4   2021-10-01 23:40:41+00:00
# ..                        ...
# 156 2021-10-31 00:27:12+00:00
# 157 2021-10-31 00:26:20+00:00
# 158 2021-10-31 00:25:17+00:00
# 159 2021-10-31 00:17:23+00:00
# 160 2021-10-31 00:15:46+00:00
#
#                                                content  \
# 0    U.S. #COVID19 death toll pass 700,000 \nKeep i...
# 1    @VicGovDH How many vaccinated people have died...
# 2    #COVID19 #DeltaVariant #Teachers https://t.co/...
# 3    "Leigh Sales" this is what you should've said!...
# 4    Few are suggesting that "the nature of transmi...
# ..                                                 ...
# 156  THE VIRAL LOAD FROM THE DELTA VARIANT IS 1200 ...
# 157  New type of 'Delta variant' is spreading in De...
# 158  Iove seeing everyone #vaccinated lying to them...
# 159  #coronavirus #SARSCoV2 #COVID19 #DeltaVariant ...
# 160  #Covid_19 #COVIDー19 #Delta #DeltaVariant \nUS ...
#
#                                        renderedContent                   id  \
# 0    U.S. #COVID19 death toll pass 700,000 \nKeep i...  1444089555397742593
# 1    @VicGovDH How many vaccinated people have died...  1444087258353520642
# 2    #COVID19 #DeltaVariant #Teachers twitter.com/M...  1444086440946700295
# 3    "Leigh Sales" this is what you should've said!...  1444085648072134662
# 4    Few are suggesting that "the nature of transmi...  1444084887154094083
# ..                                                 ...                  ...
# 156  THE VIRAL LOAD FROM THE DELTA VARIANT IS 1200 ...  1454605840326004745
# 157  New type of 'Delta variant' is spreading in De...  1454605622469697539
# 158  Iove seeing everyone #vaccinated lying to them...  1454605357825724416
# 159  #coronavirus #SARSCoV2 #COVID19 #DeltaVariant ...  1454603370056929282
# 160  #Covid_19 #COVIDー19 #Delta #DeltaVariant \nUS ...  1454602965696798722
#
#                                                   user  replyCount  \
# 0    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1    {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 2    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 3    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 4    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# ..                                                 ...         ...
# 156  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 157  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 158  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 159  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 160  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#      retweetCount  likeCount  ...  \
# 0               0          0  ...
# 1               1          3  ...
# 2               0          0  ...
# 3               1          4  ...
# 4               0          1  ...
# ..            ...        ...  ...
# 156             0          0  ...
# 157             0          1  ...
# 158             2          2  ...
# 159             0          0  ...
# 160             0          0  ...
#
#                                                  media  retweetedTweet  \
# 0                                                 None             NaN
# 1                                                 None             NaN
# 2                                                 None             NaN
# 3                                                 None             NaN
# 4                                                 None             NaN
# ..                                                 ...             ...
# 156  [{'_type': 'snscrape.modules.twitter.Video', '...             NaN
# 157  [{'_type': 'snscrape.modules.twitter.Photo', '...             NaN
# 158  [{'_type': 'snscrape.modules.twitter.Gif', 'th...             NaN
# 159                                               None             NaN
# 160  [{'_type': 'snscrape.modules.twitter.Photo', '...             NaN
#
#                                            quotedTweet inReplyToTweetId  \
# 0                                                 None              NaN
# 1                                                 None     1.444076e+18
# 2    {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 3                                                 None              NaN
# 4    {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# ..                                                 ...              ...
# 156                                               None              NaN
# 157                                               None              NaN
# 158                                               None              NaN
# 159  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 160                                               None              NaN
#
#                                          inReplyToUser  \
# 0                                                 None
# 1    {'_type': 'snscrape.modules.twitter.User', 'us...
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 156                                               None
# 157                                               None
# 158                                               None
# 159                                               None
# 160                                               None
#
#                                         mentionedUsers coordinates place  \
# 0                                                 None        None  None
# 1    [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
# 2                                                 None        None  None
# 3                                                 None        None  None
# 4    [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
# ..                                                 ...         ...   ...
# 156                                               None         NaN   NaN
# 157                                               None         NaN   NaN
# 158                                               None         NaN   NaN
# 159                                               None         NaN   NaN
# 160                                               None         NaN   NaN
#
#                                               hashtags  cashtags
# 0                     [COVID19, DeltaVariant, October]      None
# 1                                       [DeltaVariant]      None
# 2                    [COVID19, DeltaVariant, Teachers]      None
# 3                               [DeltaVariant, abc730]      None
# 4                   [unvaccinated, bced, DeltaVariant]      None
# ..                                                 ...       ...
# 156                                     [DeltaVariant]       NaN
# 157                            [DeltaVariant, Denmark]       NaN
# 158  [vaccinated, breakthrough, VaccineFailure, COV...       NaN
# 159  [coronavirus, SARSCoV2, COVID19, DeltaVariant,...       NaN
# 160          [Covid_19, COVIDー19, Delta, DeltaVariant]       NaN
#
# [5879 rows x 28 columns]

# %%
result.to_csv('Deltavariant10.csv')
