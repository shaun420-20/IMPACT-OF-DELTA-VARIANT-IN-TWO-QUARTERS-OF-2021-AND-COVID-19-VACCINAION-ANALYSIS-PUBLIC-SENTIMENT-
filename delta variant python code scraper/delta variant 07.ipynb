# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# Script Author: Martin Beck
# Medium Article Follow-Along: https://medium.com/better-programming/how-to-scrape-tweets-with-snscrape-90124ed006af

# Pip install the command below if you don't have the development version of snscrape 
# !pip install git+https://github.com/JustAnotherArchivist/snscrape.git

# Run the below command if you don't already have Pandas
# !pip install pandas

# Imports
import os
import pandas as pd

# Below are two ways of scraping using CLI commands.
# Comment or uncomment as you need. If you currently run the script as is it will scrape both queries
# then output two different csv files.



# Query by text search
# Setting variables to be used in format string command below
tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-01"
until_date = "2021-07-02"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df1 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df1
# Out:
#                               _type  \
# 0    snscrape.modules.twitter.Tweet
# 1    snscrape.modules.twitter.Tweet
# 2    snscrape.modules.twitter.Tweet
# 3    snscrape.modules.twitter.Tweet
# 4    snscrape.modules.twitter.Tweet
# ..                              ...
# 195  snscrape.modules.twitter.Tweet
# 196  snscrape.modules.twitter.Tweet
# 197  snscrape.modules.twitter.Tweet
# 198  snscrape.modules.twitter.Tweet
# 199  snscrape.modules.twitter.Tweet
#
#                                                    url  \
# 0    https://twitter.com/PoliticalSphinx/status/141...
# 1    https://twitter.com/MerlinofCanada/status/1410...
# 2    https://twitter.com/FeelTheTeal/status/1410749...
# 3    https://twitter.com/JrehnJ/status/141074941880...
# 4    https://twitter.com/REALmillerfinch/status/141...
# ..                                                 ...
# 195  https://twitter.com/Anarchazazel/status/141071...
# 196  https://twitter.com/ItaOKelly/status/141071982...
# 197  https://twitter.com/myknittingwool/status/1410...
# 198  https://twitter.com/jritzsullivan/status/14107...
# 199  https://twitter.com/MancorIan/status/141071866...
#
#                          date  \
# 0   2021-07-01 23:59:17+00:00
# 1   2021-07-01 23:59:00+00:00
# 2   2021-07-01 23:57:27+00:00
# 3   2021-07-01 23:57:26+00:00
# 4   2021-07-01 23:57:16+00:00
# ..                        ...
# 195 2021-07-01 22:00:00+00:00
# 196 2021-07-01 21:59:51+00:00
# 197 2021-07-01 21:59:37+00:00
# 198 2021-07-01 21:55:16+00:00
# 199 2021-07-01 21:55:13+00:00
#
#                                                content  \
# 0    hood_medicine: If Delta was the zombie virus, ...
# 1    No data to report on #COVID19 &amp; #DeltaVari...
# 2    4th of July is a freaking go baby! No #COVID19...
# 3    Australia's Federal Government IS scrambling, ...
# 4    #Deltavariant exploits low vaccine rates, easi...
# ..                                                 ...
# 195  Het gaat snel… 😕 #COVID19 #DeltaVariant https:...
# 196  @wexfordobrien @fmcomment @RTE_PrimeTime @RTEO...
# 197  The gov trickerry with words\ntell us 8% are f...
# 198  @MarkedByCovid @WHCOVIDResponse ⬆️This is the ...
# 199  #newsnight Who is this Tory prick? Spaffer Joh...
#
#                                        renderedContent                   id  \
# 0    hood_medicine: If Delta was the zombie virus, ...  1410749885939257349
# 1    No data to report on #COVID19 &amp; #DeltaVari...  1410749811205107717
# 2    4th of July is a freaking go baby! No #COVID19...  1410749424205058053
# 3    Australia's Federal Government IS scrambling, ...  1410749418807037952
# 4    #Deltavariant exploits low vaccine rates, easi...  1410749377371508736
# ..                                                 ...                  ...
# 195  Het gaat snel… 😕 #COVID19 #DeltaVariant twitte...  1410719867335069703
# 196  @wexfordobrien @fmcomment @RTE_PrimeTime @RTEO...  1410719827887636485
# 197  The gov trickerry with words\ntell us 8% are f...  1410719769704030209
# 198  @MarkedByCovid @WHCOVIDResponse ⬆️This is the ...  1410718676211298307
# 199  #newsnight Who is this Tory prick? Spaffer Joh...  1410718662240129031
#
#                                                   user  replyCount  \
# 0    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1    {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 2    {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 3    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 4    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# ..                                                 ...         ...
# 195  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 196  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 197  {'_type': 'snscrape.modules.twitter.User', 'us...           3
# 198  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#      retweetCount  likeCount  ...  \
# 0               0          0  ...
# 1               2         13  ...
# 2               0          6  ...
# 3               0          0  ...
# 4               2          1  ...
# ..            ...        ...  ...
# 195             0          0  ...
# 196             0          0  ...
# 197             3          6  ...
# 198             2          7  ...
# 199             2          4  ...
#
#                                                  media  retweetedTweet  \
# 0    [{'_type': 'snscrape.modules.twitter.Photo', '...             NaN
# 1    [{'_type': 'snscrape.modules.twitter.Gif', 'th...             NaN
# 2    [{'_type': 'snscrape.modules.twitter.Photo', '...             NaN
# 3                                                 None             NaN
# 4                                                 None             NaN
# ..                                                 ...             ...
# 195                                               None             NaN
# 196                                               None             NaN
# 197                                               None             NaN
# 198                                               None             NaN
# 199                                               None             NaN
#
#                                            quotedTweet inReplyToTweetId  \
# 0                                                 None              NaN
# 1                                                 None              NaN
# 2                                                 None              NaN
# 3    {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 4                                                 None              NaN
# ..                                                 ...              ...
# 195  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 196                                               None     1.410715e+18
# 197                                               None              NaN
# 198                                               None     1.410715e+18
# 199                                               None              NaN
#
#                                          inReplyToUser  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 195                                               None
# 196  {'_type': 'snscrape.modules.twitter.User', 'us...
# 197                                               None
# 198  {'_type': 'snscrape.modules.twitter.User', 'us...
# 199                                               None
#
#                                         mentionedUsers coordinates place  \
# 0                                                 None        None  None
# 1                                                 None        None  None
# 2                                                 None        None  None
# 3                                                 None        None  None
# 4                                                 None        None  None
# ..                                                 ...         ...   ...
# 195                                               None        None  None
# 196  [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
# 197                                               None        None  None
# 198  [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
# 199                                               None        None  None
#
#                                               hashtags  cashtags
# 0    [HotMessSummer, GetVaccinatedAlready, ProtectY...       NaN
# 1          [COVID19, DeltaVariant, Alberta, CanadaDay]       NaN
# 2                              [COVID19, DeltaVariant]       NaN
# 3          [LNP, NSW, ideology, science, DeltaVariant]       NaN
# 4                                       [Deltavariant]       NaN
# ..                                                 ...       ...
# 195                            [COVID19, DeltaVariant]       NaN
# 196                            [COVID19, DeltaVariant]       NaN
# 197        [DeltaVariant, Sydneylockdown, sydneycovid]       NaN
# 198                      [MarkedByCOVID, DeltaVariant]       NaN
# 199  [newsnight, BodiesPiledHigh, TorySleaze, Delta...       NaN
#
# [200 rows x 28 columns]

# %%
tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-02"
until_date = "2021-07-03"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df2 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df2
# Out:
#                               _type  \
# 0    snscrape.modules.twitter.Tweet
# 1    snscrape.modules.twitter.Tweet
# 2    snscrape.modules.twitter.Tweet
# 3    snscrape.modules.twitter.Tweet
# 4    snscrape.modules.twitter.Tweet
# ..                              ...
# 195  snscrape.modules.twitter.Tweet
# 196  snscrape.modules.twitter.Tweet
# 197  snscrape.modules.twitter.Tweet
# 198  snscrape.modules.twitter.Tweet
# 199  snscrape.modules.twitter.Tweet
#
#                                                    url  \
# 0    https://twitter.com/micropainter/status/141111...
# 1    https://twitter.com/OaParallax/status/14111122...
# 2    https://twitter.com/zoglizzy4624/status/141111...
# 3    https://twitter.com/JJKALE2/status/14111120493...
# 4    https://twitter.com/scruffy65/status/141111175...
# ..                                                 ...
# 195  https://twitter.com/realPaulSchott/status/1411...
# 196  https://twitter.com/mauikanehoalani/status/141...
# 197  https://twitter.com/Roisindubh2/status/1411083...
# 198  https://twitter.com/ThiefNtheKnight/status/141...
# 199  https://twitter.com/mycookie2020/status/141108...
#
#                          date  \
# 0   2021-07-02 23:59:40+00:00
# 1   2021-07-02 23:59:07+00:00
# 2   2021-07-02 23:58:52+00:00
# 3   2021-07-02 23:58:24+00:00
# 4   2021-07-02 23:57:13+00:00
# ..                        ...
# 195 2021-07-02 22:05:02+00:00
# 196 2021-07-02 22:04:04+00:00
# 197 2021-07-02 22:04:02+00:00
# 198 2021-07-02 22:03:38+00:00
# 199 2021-07-02 22:03:16+00:00
#
#                                                content  \
# 0    @KevinCTV Thank you Coucillors @ChahalGeorge a...
# 1    Con la pandemia aumentó la intolerancia\nhttps...
# 2    Zo Glizzy “LOCKED IN” Prod. By ELO (Full Audio...
# 3    This is a sports hall in Suva, Fiji. These bed...
# 4    #Mondkapjes worden in #LosAngeles County weer ...
# ..                                                 ...
# 195  #DeltaVariant out of control in #Germany.\n\n#...
# 196  As should we all... #DeltaVariant #COVID19 htt...
# 197  "It's airborne, it's out there"...\nReporter/J...
# 198  it just their lying about souces theyd rather ...
# 199  @SBullFinance #Gomora #YouMakeStrayKidsStay #S...
#
#                                        renderedContent                   id  \
# 0    @KevinCTV Thank you Coucillors @ChahalGeorge a...  1411112369493733378
# 1    Con la pandemia aumentó la intolerancia\nefect...  1411112228351217666
# 2    Zo Glizzy “LOCKED IN” Prod. By ELO (Full Audio...  1411112167873646595
# 3    This is a sports hall in Suva, Fiji. These bed...  1411112049325723654
# 4    #Mondkapjes worden in #LosAngeles County weer ...  1411111751626731520
# ..                                                 ...                  ...
# 195  #DeltaVariant out of control in #Germany.\n\n#...  1411083521880477696
# 196  As should we all... #DeltaVariant #COVID19 twi...  1411083277281026052
# 197  "It's airborne, it's out there"...\nReporter/J...  1411083269404254213
# 198  it just their lying about souces theyd rather ...  1411083167780413446
# 199  @SBullFinance #Gomora #YouMakeStrayKidsStay #S...  1411083075996557315
#
#                                                   user  replyCount  \
# 0    {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 1    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 3    {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 4    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# ..                                                 ...         ...
# 195  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 196  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 197  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 198  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#      retweetCount  likeCount  ...  media  retweetedTweet  \
# 0               4         11  ...   None             NaN
# 1               0          0  ...   None             NaN
# 2               0          0  ...   None             NaN
# 3               1         12  ...   None             NaN
# 4               0          0  ...   None             NaN
# ..            ...        ...  ...    ...             ...
# 195             0          0  ...   None             NaN
# 196             0          6  ...   None             NaN
# 197             1          1  ...   None             NaN
# 198             0          0  ...   None             NaN
# 199             0          0  ...   None             NaN
#
#                                            quotedTweet inReplyToTweetId  \
# 0                                                 None     1.411017e+18
# 1                                                 None              NaN
# 2                                                 None              NaN
# 3    {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 4    {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# ..                                                 ...              ...
# 195  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 196  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 197  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 198                                               None              NaN
# 199                                               None     1.410135e+18
#
#                                          inReplyToUser  \
# 0    {'_type': 'snscrape.modules.twitter.User', 'us...
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 195                                               None
# 196                                               None
# 197                                               None
# 198                                               None
# 199  {'_type': 'snscrape.modules.twitter.User', 'us...
#
#                                         mentionedUsers coordinates place  \
# 0    [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
# 1                                                 None        None  None
# 2    [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
# 3    [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
# 4                                                 None        None  None
# ..                                                 ...         ...   ...
# 195                                               None        None  None
# 196                                               None        None  None
# 197                                               None        None  None
# 198                                               None        None  None
# 199                                               None        None  None
#
#                                               hashtags  cashtags
# 0                [yyccc, yyc, DeltaVariant, covid19AB]      None
# 1    [COVID19, Covid, Miami, pandemic, BuenosDias, ...      None
# 2                  [Exclusive, dogecoin, DeltaVariant]      None
# 3                 [DeltaVariant, Covid19Fiji, COVID19]      None
# 4      [Mondkapjes, LosAngeles, COVID19, DeltaVariant]      None
# ..                                                 ...       ...
# 195  [DeltaVariant, Germany, plandemie, lockdownfor...      None
# 196                            [DeltaVariant, COVID19]      None
# 197                      [CovidAirborne, DeltaVariant]      None
# 198                                     [DeltaVariant]      None
# 199  [Gomora, YouMakeStrayKidsStay, SkeemSaam, Madd...      None
#
# [200 rows x 28 columns]

# %%
tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-03"
until_date = "2021-07-04"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df3 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df3
# Out:
#                               _type  \
# 0    snscrape.modules.twitter.Tweet
# 1    snscrape.modules.twitter.Tweet
# 2    snscrape.modules.twitter.Tweet
# 3    snscrape.modules.twitter.Tweet
# 4    snscrape.modules.twitter.Tweet
# ..                              ...
# 195  snscrape.modules.twitter.Tweet
# 196  snscrape.modules.twitter.Tweet
# 197  snscrape.modules.twitter.Tweet
# 198  snscrape.modules.twitter.Tweet
# 199  snscrape.modules.twitter.Tweet
#
#                                                    url  \
# 0    https://twitter.com/SherryPCMO/status/14114747...
# 1    https://twitter.com/Valerie2a/status/141147475...
# 2    https://twitter.com/diamondbacknl/status/14114...
# 3    https://twitter.com/ActionTime/status/14114730...
# 4    https://twitter.com/athousandmoms/status/14114...
# ..                                                 ...
# 195  https://twitter.com/Joycelou71/status/14114394...
# 196  https://twitter.com/maskcapecod/status/1411439...
# 197  https://twitter.com/Jim_Pembroke/status/141143...
# 198  https://twitter.com/xoristrastimesi/status/141...
# 199  https://twitter.com/NancyLowell/status/1411439...
#
#                          date  \
# 0   2021-07-03 23:59:49+00:00
# 1   2021-07-03 23:59:38+00:00
# 2   2021-07-03 23:56:15+00:00
# 3   2021-07-03 23:52:58+00:00
# 4   2021-07-03 23:50:19+00:00
# ..                        ...
# 195 2021-07-03 21:39:17+00:00
# 196 2021-07-03 21:38:13+00:00
# 197 2021-07-03 21:37:42+00:00
# 198 2021-07-03 21:37:38+00:00
# 199 2021-07-03 21:37:37+00:00
#
#                                                content  \
# 0    @B52Malmet I bet #Hawley and #Blunt are vaccin...
# 1    #DeltaVariant Vous pouvez tous, vous prévaloir...
# 2    Alle #wappies - opgelet! Met de #DeltaVariant ...
# 3    #CovidEmergency 2021: #Delta Variant Goes Glob...
# 4    The #vaccine protects you from the #DeltaVaria...
# ..                                                 ...
# 195  @AnaCabrera But my county\area Mesa County/Gra...
# 196  From NYT #Coronavirus Briefing -- 7/2/21:\nWit...
# 197  Other states did a short sharp #lockdown,\nAnd...
# 198  #εμβόλια #εμβολια #εμβολιο #εμβόλιο #εμβολιασμ...
# 199  @jeremynewberger I think it's a lost cause.\nT...
#
#                                        renderedContent                   id  \
# 0    @B52Malmet I bet #Hawley and #Blunt are vaccin...  1411474792734072833
# 1    #DeltaVariant Vous pouvez tous, vous prévaloir...  1411474750002577415
# 2    Alle #wappies - opgelet! Met de #DeltaVariant ...  1411473898101690372
# 3    #CovidEmergency 2021: #Delta Variant Goes Glob...  1411473070842204165
# 4    The #vaccine protects you from the #DeltaVaria...  1411472404237500420
# ..                                                 ...                  ...
# 195  @AnaCabrera But my county\area Mesa County/Gra...  1411439427516129280
# 196  From NYT #Coronavirus Briefing -- 7/2/21:\nWit...  1411439158757896198
# 197  Other states did a short sharp #lockdown,\nAnd...  1411439028889481219
# 198  #εμβόλια #εμβολια #εμβολιο #εμβόλιο #εμβολιασμ...  1411439012053766148
# 199  @jeremynewberger I think it's a lost cause.\nT...  1411439008836558851
#
#                                                   user  replyCount  \
# 0    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2    {'_type': 'snscrape.modules.twitter.User', 'us...           5
# 3    {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 4    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# ..                                                 ...         ...
# 195  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 196  {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 197  {'_type': 'snscrape.modules.twitter.User', 'us...          28
# 198  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#      retweetCount  likeCount  ...  \
# 0               0          0  ...
# 1               0          0  ...
# 2               0          1  ...
# 3               4          3  ...
# 4               0          0  ...
# ..            ...        ...  ...
# 195             0          0  ...
# 196             0          0  ...
# 197           145        566  ...
# 198             1          1  ...
# 199             0          2  ...
#
#                                                  media  retweetedTweet  \
# 0                                                 None             NaN
# 1                                                 None             NaN
# 2                                                 None             NaN
# 3                                                 None             NaN
# 4    [{'_type': 'snscrape.modules.twitter.Photo', '...             NaN
# ..                                                 ...             ...
# 195                                               None             NaN
# 196                                               None             NaN
# 197                                               None             NaN
# 198                                               None             NaN
# 199                                               None             NaN
#
#                                            quotedTweet inReplyToTweetId  \
# 0                                                 None     1.411462e+18
# 1                                                 None              NaN
# 2    {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 3                                                 None              NaN
# 4                                                 None              NaN
# ..                                                 ...              ...
# 195                                               None     1.411415e+18
# 196                                               None              NaN
# 197                                               None              NaN
# 198  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 199                                               None     1.411339e+18
#
#                                          inReplyToUser  \
# 0    {'_type': 'snscrape.modules.twitter.User', 'us...
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 195  {'_type': 'snscrape.modules.twitter.User', 'us...
# 196                                               None
# 197                                               None
# 198                                               None
# 199  {'_type': 'snscrape.modules.twitter.User', 'us...
#
#                                         mentionedUsers coordinates place  \
# 0    [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
# 1                                                 None        None  None
# 2    [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
# 3                                                 None        None  None
# 4                                                 None        None  None
# ..                                                 ...         ...   ...
# 195  [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
# 196                                               None        None  None
# 197                                               None        None  None
# 198                                               None        None  None
# 199  [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#
#                                               hashtags  cashtags
# 0                        [Hawley, Blunt, DeltaVariant]      None
# 1                                       [DeltaVariant]      None
# 2    [wappies, DeltaVariant, willemengel, GetVaccin...      None
# 3    [CovidEmergency, Delta, VaccineForALL, Vaccine...      None
# 4                              [vaccine, DeltaVariant]      None
# ..                                                 ...       ...
# 195                                     [DeltaVariant]      None
# 196            [Coronavirus, vaccinated, Deltavariant]      None
# 197       [lockdown, DeltaVariant, mockdown, covidnsw]      None
# 198  [εμβόλια, εμβολια, εμβολιο, εμβόλιο, εμβολιασμ...      None
# 199                                     [DeltaVariant]      None
#
# [200 rows x 28 columns]

# %%
tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-04"
until_date = "2021-07-05"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df4 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df4
# Out:
#                               _type  \
# 0    snscrape.modules.twitter.Tweet
# 1    snscrape.modules.twitter.Tweet
# 2    snscrape.modules.twitter.Tweet
# 3    snscrape.modules.twitter.Tweet
# 4    snscrape.modules.twitter.Tweet
# ..                              ...
# 195  snscrape.modules.twitter.Tweet
# 196  snscrape.modules.twitter.Tweet
# 197  snscrape.modules.twitter.Tweet
# 198  snscrape.modules.twitter.Tweet
# 199  snscrape.modules.twitter.Tweet
#
#                                                    url  \
# 0    https://twitter.com/westcoastereliz/status/141...
# 1    https://twitter.com/tourleaderluke/status/1411...
# 2    https://twitter.com/fredshesaid1/status/141183...
# 3    https://twitter.com/PdmMatters/status/14118357...
# 4    https://twitter.com/AAuscham/status/1411835458...
# ..                                                 ...
# 195  https://twitter.com/gottaluvralph/status/14117...
# 196  https://twitter.com/DregsFrolics/status/141179...
# 197  https://twitter.com/vahinee_i/status/141179529...
# 198  https://twitter.com/ImpunityCity/status/141179...
# 199  https://twitter.com/David23562606/status/14117...
#
#                          date  \
# 0   2021-07-04 23:58:56+00:00
# 1   2021-07-04 23:54:37+00:00
# 2   2021-07-04 23:54:31+00:00
# 3   2021-07-04 23:54:12+00:00
# 4   2021-07-04 23:52:58+00:00
# ..                        ...
# 195 2021-07-04 21:14:02+00:00
# 196 2021-07-04 21:13:55+00:00
# 197 2021-07-04 21:13:22+00:00
# 198 2021-07-04 21:12:24+00:00
# 199 2021-07-04 21:12:09+00:00
#
#                                                content  \
# 0    @bcfamilyca #MaskUp for me inside anywhere. No...
# 1    The morning crowds off the trains are usually ...
# 2    The #DeltaVariant may have something to say ab...
# 3    People who have chosen not to take the experim...
# 4    #australia #coronavírus #covidー19 #deltavarian...
# ..                                                 ...
# 195  @thehill @FLOTUS I adore FLOTUS and POTUS. \n\...
# 196  @TheBlueGem3 Had my second Pfizer shot today, ...
# 197  La menace du Delta plane #DeltaVariant #Delta ...
# 198  Whoever smelt it, contracted it and dealt it. ...
# 199  No brainer really but you carry on cause your ...
#
#                                        renderedContent                   id  \
# 0    @bcfamilyca #MaskUp for me inside anywhere. No...  1411836958423216129
# 1    The morning crowds off the trains are usually ...  1411835874711539715
# 2    The #DeltaVariant may have something to say ab...  1411835846240702468
# 3    People who have chosen not to take the experim...  1411835768419635202
# 4    #australia #coronavírus #covidー19 #deltavarian...  1411835458699640833
# ..                                                 ...                  ...
# 195  @thehill @FLOTUS I adore FLOTUS and POTUS. \n\...  1411795461778837509
# 196  @TheBlueGem3 Had my second Pfizer shot today, ...  1411795433370705920
# 197  La menace du Delta plane #DeltaVariant #Delta ...  1411795293859991554
# 198  Whoever smelt it, contracted it and dealt it. ...  1411795049621430274
# 199  No brainer really but you carry on cause your ...  1411794987495395329
#
#                                                   user  replyCount  \
# 0    {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 1    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 3    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 4    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# ..                                                 ...         ...
# 195  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 196  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 197  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 198  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#      retweetCount  likeCount  ...  \
# 0               4          3  ...
# 1               0          3  ...
# 2               1          2  ...
# 3               0          1  ...
# 4               0          0  ...
# ..            ...        ...  ...
# 195             0          0  ...
# 196             0          1  ...
# 197             0          0  ...
# 198             1          0  ...
# 199             0          0  ...
#
#                                                  media  retweetedTweet  \
# 0                                                 None             NaN
# 1    [{'_type': 'snscrape.modules.twitter.Photo', '...             NaN
# 2                                                 None             NaN
# 3                                                 None             NaN
# 4                                                 None             NaN
# ..                                                 ...             ...
# 195  [{'_type': 'snscrape.modules.twitter.Gif', 'th...             NaN
# 196                                               None             NaN
# 197                                               None             NaN
# 198                                               None             NaN
# 199                                               None             NaN
#
#                                            quotedTweet inReplyToTweetId  \
# 0                                                 None     1.411836e+18
# 1                                                 None              NaN
# 2    {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 3                                                 None              NaN
# 4                                                 None              NaN
# ..                                                 ...              ...
# 195                                               None     1.411450e+18
# 196                                               None     1.411417e+18
# 197  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 198  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 199  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
#
#                                          inReplyToUser  \
# 0    {'_type': 'snscrape.modules.twitter.User', 'us...
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 195  {'_type': 'snscrape.modules.twitter.User', 'us...
# 196  {'_type': 'snscrape.modules.twitter.User', 'us...
# 197                                               None
# 198                                               None
# 199                                               None
#
#                                         mentionedUsers coordinates place  \
# 0    [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
# 1                                                 None        None  None
# 2                                                 None        None  None
# 3                                                 None        None  None
# 4                                                 None        None  None
# ..                                                 ...         ...   ...
# 195  [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
# 196  [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
# 197                                               None        None  None
# 198                                               None        None  None
# 199                                               None        None  None
#
#                                               hashtags  cashtags
# 0    [MaskUp, Canada, FullyVaccinated, DeltaVariant...      None
# 1    [sydneylockdown, Australia, DeltaVariant, covi...      None
# 2                                       [DeltaVariant]      None
# 3                        [mRNA, DeltaVariant, VACCINE]      None
# 4     [australia, coronavírus, covidー19, deltavariant]      None
# ..                                                 ...       ...
# 195                                     [DeltaVariant]      None
# 196                                     [DeltaVariant]      None
# 197                              [DeltaVariant, Delta]      None
# 198                                     [DeltaVariant]      None
# 199                          [WearAMask, DeltaVariant]      None
#
# [200 rows x 28 columns]

# %%
tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-05"
until_date = "2021-07-06"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df5 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df5


tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-06"
until_date = "2021-07-07"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df6 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df6


tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-07"
until_date = "2021-07-08"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df7 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df7


tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-08"
until_date = "2021-07-09"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df8 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df8



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-09"
until_date = "2021-07-10"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df9 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df9




tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-10"
until_date = "2021-07-11"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df10 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df10



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-11"
until_date = "2021-07-12"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df11= pd.read_json('text-query-tweets.json', lines=True)
tweets_df11




tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-12"
until_date = "2021-07-13"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df12 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df12



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-13"
until_date = "2021-07-14"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df13 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df13



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-14"
until_date = "2021-07-15"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df14 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df14



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-15"
until_date = "2021-07-16"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df15 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df15



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-16"
until_date = "2021-07-17"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df16 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df16


tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-17"
until_date = "2021-07-18"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df17 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df17




tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-18"
until_date = "2021-07-19"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df18 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df18



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-19"
until_date = "2021-07-20"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df19 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df19






tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-20"
until_date = "2021-07-21"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df20 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df20


tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-21"
until_date = "2021-07-22"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df21 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df21




tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-22"
until_date = "2021-07-23"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df22 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df22



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-23"
until_date = "2021-07-24"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df23 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df23





tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-24"
until_date = "2021-07-25"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df24 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df24



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-25"
until_date = "2021-07-26"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df25 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df25


tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-26"
until_date = "2021-07-27"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df26 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df26



tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-27"
until_date = "2021-07-28"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df27 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df27


tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-28"
until_date = "2021-07-29"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df28= pd.read_json('text-query-tweets.json', lines=True)
tweets_df28


tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-29"
until_date = "2021-07-30"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df29 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df29


tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-30"
until_date = "2021-07-31"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df30 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df30




tweet_count = 200
text_query = "#DeltaVariant"
since_date = "2021-07-31"
until_date = "2021-08-01"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df31 = pd.read_json('text-query-tweets.json', lines=True)
tweets_df31
# Out:
#                               _type  \
# 0    snscrape.modules.twitter.Tweet
# 1    snscrape.modules.twitter.Tweet
# 2    snscrape.modules.twitter.Tweet
# 3    snscrape.modules.twitter.Tweet
# 4    snscrape.modules.twitter.Tweet
# ..                              ...
# 195  snscrape.modules.twitter.Tweet
# 196  snscrape.modules.twitter.Tweet
# 197  snscrape.modules.twitter.Tweet
# 198  snscrape.modules.twitter.Tweet
# 199  snscrape.modules.twitter.Tweet
#
#                                                    url  \
# 0    https://twitter.com/yuccaldo/status/1421621666...
# 1    https://twitter.com/erkdeni/status/14216215412...
# 2    https://twitter.com/atrinoshiesque/status/1421...
# 3    https://twitter.com/Mrs_Cldh/status/1421621300...
# 4    https://twitter.com/amsmadwoman/status/1421621...
# ..                                                 ...
# 195  https://twitter.com/arunningriot/status/142160...
# 196  https://twitter.com/DRyanRieux/status/14216078...
# 197  https://twitter.com/randman_0514/status/142160...
# 198  https://twitter.com/rao_n10/status/14216078028...
# 199  https://twitter.com/tallchick1966/status/14216...
#
#                          date  \
# 0   2021-07-31 23:59:52+00:00
# 1   2021-07-31 23:59:22+00:00
# 2   2021-07-31 23:58:56+00:00
# 3   2021-07-31 23:58:25+00:00
# 4   2021-07-31 23:57:53+00:00
# ..                        ...
# 195 2021-07-31 23:05:15+00:00
# 196 2021-07-31 23:04:57+00:00
# 197 2021-07-31 23:04:51+00:00
# 198 2021-07-31 23:04:47+00:00
# 199 2021-07-31 23:04:39+00:00
#
#                                                content  \
# 0    @ModerniMuija @alanenata @meripu @oajry @liand...
# 1    "#Covid #vaccine #booster shots for #DeltaVari...
# 2    As #Pfizer and #Moderna push on ahead for boos...
# 3    Lollapalooza Begins in Chicago, and It Is Pack...
# 4    @ritaresarian We really need some data and som...
# ..                                                 ...
# 195  “DeSantis has resisted mandatory mask mandates...
# 196  #DeltaVariant, know the facts.. https://t.co/n...
# 197  Most Democrats have vaccination cards. Most Re...
# 198  Exceeded 1000 cases two days in a row now.  #D...
# 199  #ivermectinworks #DeltaVariant https://t.co/jW...
#
#                                        renderedContent                   id  \
# 0    @ModerniMuija @alanenata @meripu @oajry @liand...  1421621666120089605
# 1    "#Covid #vaccine #booster shots for #DeltaVari...  1421621541285027840
# 2    As #Pfizer and #Moderna push on ahead for boos...  1421621432291844106
# 3    Lollapalooza Begins in Chicago, and It Is Pack...  1421621300255248384
# 4    @ritaresarian We really need some data and som...  1421621169501900807
# ..                                                 ...                  ...
# 195  “DeSantis has resisted mandatory mask mandates...  1421607922908508161
# 196  #DeltaVariant, know the facts.. twitter.com/sy...  1421607848614707203
# 197  Most Democrats have vaccination cards. Most Re...  1421607822580649992
# 198  Exceeded 1000 cases two days in a row now.  #D...  1421607802804572160
# 199  #ivermectinworks #DeltaVariant twitter.com/Pie...  1421607770869149703
#
#                                                   user  replyCount  \
# 0    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 3    {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 4    {'_type': 'snscrape.modules.twitter.User', 'us...           1
# ..                                                 ...         ...
# 195  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 196  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 197  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 198  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#      retweetCount  likeCount  ...  \
# 0               0          2  ...
# 1               2          1  ...
# 2               0          0  ...
# 3               0          0  ...
# 4               0          1  ...
# ..            ...        ...  ...
# 195             0          0  ...
# 196             0          0  ...
# 197             0          0  ...
# 198             0          0  ...
# 199             0          0  ...
#
#                                                  media  retweetedTweet  \
# 0    [{'_type': 'snscrape.modules.twitter.Photo', '...             NaN
# 1                                                 None             NaN
# 2                                                 None             NaN
# 3    [{'_type': 'snscrape.modules.twitter.Photo', '...             NaN
# 4                                                 None             NaN
# ..                                                 ...             ...
# 195                                               None             NaN
# 196                                               None             NaN
# 197                                               None             NaN
# 198                                               None             NaN
# 199                                               None             NaN
#
#                                            quotedTweet inReplyToTweetId  \
# 0    {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 1                                                 None              NaN
# 2                                                 None              NaN
# 3                                                 None              NaN
# 4                                                 None     1.421621e+18
# ..                                                 ...              ...
# 195                                               None              NaN
# 196  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 197  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 198  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 199  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
#
#                                          inReplyToUser  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4    {'_type': 'snscrape.modules.twitter.User', 'us...
# ..                                                 ...
# 195                                               None
# 196                                               None
# 197                                               None
# 198                                               None
# 199                                               None
#
#                                         mentionedUsers coordinates place  \
# 0    [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
# 1    [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
# 2                                                 None        None  None
# 3                                                 None        None  None
# 4    [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
# ..                                                 ...         ...   ...
# 195                                               None        None  None
# 196                                               None        None  None
# 197                                               None        None  None
# 198                                               None        None  None
# 199                                               None        None  None
#
#                                               hashtags  cashtags
# 0                                       [DeltaVariant]       NaN
# 1    [Covid, vaccine, booster, DeltaVariant, Report...       NaN
# 2    [Pfizer, Moderna, CovidVaccine, COVID19, Delta...       NaN
# 3    [Lollapalooza2021, SHUTDOWN, DeltaVariant, COV...       NaN
# 4                                       [DeltaVariant]       NaN
# ..                                                 ...       ...
# 195               [COVID19, DeathSantis, DeltaVariant]       NaN
# 196                                     [DeltaVariant]       NaN
# 197  [JrIsAnIdiot, COVID, DeltaVariant, GetVaccinat...       NaN
# 198                                     [DeltaVariant]       NaN
# 199                    [ivermectinworks, DeltaVariant]       NaN
#
# [200 rows x 28 columns]

# %%
result = pd.concat([tweets_df1,tweets_df2, tweets_df3,tweets_df4,tweets_df5,tweets_df6,tweets_df7,tweets_df8,tweets_df9,tweets_df10,tweets_df11,tweets_df12,tweets_df13,tweets_df14,tweets_df15,tweets_df16,tweets_df17,tweets_df18,tweets_df19,tweets_df20,tweets_df21,tweets_df22,tweets_df23,tweets_df24,tweets_df25,tweets_df26,tweets_df27,tweets_df28,tweets_df29,tweets_df30],  join="inner")
result
# Out:
#                               _type  \
# 0    snscrape.modules.twitter.Tweet
# 1    snscrape.modules.twitter.Tweet
# 2    snscrape.modules.twitter.Tweet
# 3    snscrape.modules.twitter.Tweet
# 4    snscrape.modules.twitter.Tweet
# ..                              ...
# 195  snscrape.modules.twitter.Tweet
# 196  snscrape.modules.twitter.Tweet
# 197  snscrape.modules.twitter.Tweet
# 198  snscrape.modules.twitter.Tweet
# 199  snscrape.modules.twitter.Tweet
#
#                                                    url  \
# 0    https://twitter.com/PoliticalSphinx/status/141...
# 1    https://twitter.com/MerlinofCanada/status/1410...
# 2    https://twitter.com/FeelTheTeal/status/1410749...
# 3    https://twitter.com/JrehnJ/status/141074941880...
# 4    https://twitter.com/REALmillerfinch/status/141...
# ..                                                 ...
# 195  https://twitter.com/OneBreathHOU/status/142124...
# 196  https://twitter.com/TheRealStuart_/status/1421...
# 197  https://twitter.com/ctjay14/status/14212492982...
# 198  https://twitter.com/MightyMommy024/status/1421...
# 199  https://twitter.com/politstrip/status/14212492...
#
#                          date  \
# 0   2021-07-01 23:59:17+00:00
# 1   2021-07-01 23:59:00+00:00
# 2   2021-07-01 23:57:27+00:00
# 3   2021-07-01 23:57:26+00:00
# 4   2021-07-01 23:57:16+00:00
# ..                        ...
# 195 2021-07-30 23:21:12+00:00
# 196 2021-07-30 23:20:51+00:00
# 197 2021-07-30 23:20:12+00:00
# 198 2021-07-30 23:20:11+00:00
# 199 2021-07-30 23:20:09+00:00
#
#                                                content  \
# 0    hood_medicine: If Delta was the zombie virus, ...
# 1    No data to report on #COVID19 &amp; #DeltaVari...
# 2    4th of July is a freaking go baby! No #COVID19...
# 3    Australia's Federal Government IS scrambling, ...
# 4    #Deltavariant exploits low vaccine rates, easi...
# ..                                                 ...
# 195  As we contend with the #DeltaVariant in Texas,...
# 196  @Angry_Staffer They REALLY don’t care about ma...
# 197  Live look at the Delta Variant enjoying Lollap...
# 198  Number of deaths from #COVID19 : 4,222,876\n\n...
# 199  THERE IS NO TEST FOR THE #DeltaVariant !! \n\n...
#
#                                        renderedContent                   id  \
# 0    hood_medicine: If Delta was the zombie virus, ...  1410749885939257349
# 1    No data to report on #COVID19 &amp; #DeltaVari...  1410749811205107717
# 2    4th of July is a freaking go baby! No #COVID19...  1410749424205058053
# 3    Australia's Federal Government IS scrambling, ...  1410749418807037952
# 4    #Deltavariant exploits low vaccine rates, easi...  1410749377371508736
# ..                                                 ...                  ...
# 195  As we contend with the #DeltaVariant in Texas,...  1421249548958175232
# 196  @Angry_Staffer They REALLY don’t care about ma...  1421249459716042755
# 197  Live look at the Delta Variant enjoying Lollap...  1421249298231173121
# 198  Number of deaths from #COVID19 : 4,222,876\n\n...  1421249293357404163
# 199  THERE IS NO TEST FOR THE #DeltaVariant !! \n\n...  1421249282909171713
#
#                                                   user  replyCount  \
# 0    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1    {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 2    {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 3    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 4    {'_type': 'snscrape.modules.twitter.User', 'us...           0
# ..                                                 ...         ...
# 195  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 196  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 197  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 198  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199  {'_type': 'snscrape.modules.twitter.User', 'us...           4
#
#      retweetCount  likeCount  ...  \
# 0               0          0  ...
# 1               2         13  ...
# 2               0          6  ...
# 3               0          0  ...
# 4               2          1  ...
# ..            ...        ...  ...
# 195             9          6  ...
# 196             1          7  ...
# 197             0          0  ...
# 198             0          0  ...
# 199            20         24  ...
#
#                                                  media  retweetedTweet  \
# 0    [{'_type': 'snscrape.modules.twitter.Photo', '...             NaN
# 1    [{'_type': 'snscrape.modules.twitter.Gif', 'th...             NaN
# 2    [{'_type': 'snscrape.modules.twitter.Photo', '...             NaN
# 3                                                 None             NaN
# 4                                                 None             NaN
# ..                                                 ...             ...
# 195                                               None             NaN
# 196                                               None             NaN
# 197  [{'_type': 'snscrape.modules.twitter.Gif', 'th...             NaN
# 198                                               None             NaN
# 199                                               None             NaN
#
#                                            quotedTweet inReplyToTweetId  \
# 0                                                 None              NaN
# 1                                                 None              NaN
# 2                                                 None              NaN
# 3    {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 4                                                 None              NaN
# ..                                                 ...              ...
# 195                                               None              NaN
# 196                                               None     1.421242e+18
# 197                                               None              NaN
# 198                                               None              NaN
# 199  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
#
#                                          inReplyToUser  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 195                                               None
# 196  {'_type': 'snscrape.modules.twitter.User', 'us...
# 197                                               None
# 198                                               None
# 199                                               None
#
#                                         mentionedUsers coordinates place  \
# 0                                                 None        None  None
# 1                                                 None        None  None
# 2                                                 None        None  None
# 3                                                 None        None  None
# 4                                                 None        None  None
# ..                                                 ...         ...   ...
# 195                                               None        None  None
# 196  [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
# 197                                               None        None  None
# 198                                               None        None  None
# 199                                               None        None  None
#
#                                               hashtags  cashtags
# 0    [HotMessSummer, GetVaccinatedAlready, ProtectY...       NaN
# 1          [COVID19, DeltaVariant, Alberta, CanadaDay]       NaN
# 2                              [COVID19, DeltaVariant]       NaN
# 3          [LNP, NSW, ideology, science, DeltaVariant]       NaN
# 4                                       [Deltavariant]       NaN
# ..                                                 ...       ...
# 195                            [DeltaVariant, COVID19]      None
# 196  [GetVaccinated, WearAMask, DeltaVariant, ItsNo...      None
# 197  [Lollapalooza, DeltaVariant, Lollapalooza2021,...      None
# 198  [COVID19, Masks, DeathSantis, coronavirus, Del...      None
# 199                                     [DeltaVariant]      None
#
# [6000 rows x 28 columns]

# %%
result.to_csv('Deltavariant07.csv')
